# %%
import requests
import pprint
import selenium
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import os

from dotenv import load_dotenv


os.chdir('C:/Users/steve/web-scraping/database')

from crud_functions import write_dataframes_to_db, df_to_sql
from models import Software_Engineer_Levels_Fyi
from sqlalchemy import Engine

# %%
os.chdir('C:/Users/steve/web-scraping/salaries')
from salaries_functions import *

# %%
salaries_url = 'https://levels.fyi/t/software-engineer/locations/greater-paris-area'
driver = webdriver.Chrome()
sign_in_levels_fyi(driver)
driver.get(salaries_url)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="dc413bed1592ed6ef29376f65ecb160c", element="f.9EF7102E711703C1376B5D13204377BE.d.1A38726F97675701B56AC109F25E889E.e.8")>
# Cookies accepted.

# %%
WebDriverWait(driver, 10).until(
    EC.element_to_be_clickable((By.XPATH, '//button[normalize-space(text())="2"]'))
).click()

# %%
next_button = driver.find_element(By.XPATH, '//*[@id="__next"]/div/div[2]/div[3]/div[2]/div[2]/table/tfoot/tr/td/div/div[2]/div/button[7]')
next_button.click()
