# %%
#paremeters
salaries_url = '1'
location = '2'
is_at_second_page = False

# %%
from salaries_functions import *
import requests
import pprint
import selenium
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import os

from dotenv import load_dotenv


os.chdir('C:/Users/steve/web-scraping/database')

from crud_functions import write_dataframes_to_db, df_to_sql
from models import software_engineer_salaries
from sqlalchemy import Engine

# %%
salaries_url = 'https://www.levels.fyi/t/software-engineer/locations/netherlands'
driver = webdriver.Chrome()
sign_in_levels_fyi(driver)
driver.get(salaries_url)


driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)


# the is at second page value should be set to False, apart for when scraping data from
# Germany, or the Netherlands
data = scrape_pages_for_lyi(driver, is_at_second_page)
df = parse_list_to_df(data)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="6ea10a91f731d9f0d3a9ce2916dff1f0", element="f.AEEAD692874A51823725A055B2FF077F.d.3FA65C0FE6DBD6A0C5AFF7FA5AD2DB84.e.8")>
# Cookies accepted.
# ['Spotify', 'Senior Engineer', '14  yrs', 'Amsterdam, NH, Netherlands | an hour ago', '10,6\xa0χιλ. | N/A | N/A']
# ['ABN AMRO', 'L3', '2  yrs', 'Amsterdam, NH, Netherlands | 3 hours ago', '5\xa0χιλ. | N/A | N/A']
# ['Reaktor', 'L3', '10  yrs', 'Amsterdam, NH, Netherlands | a day ago', '6,1\xa0χιλ. | N/A | N/A']
# ['Ace&tate', 'Senior', '9  yrs', 'Amsterdam, NH, Netherlands | a day ago', '6,3\xa0χιλ. | N/A | N/A']
# ['Gerimedica', 'L3', '7  yrs', 'Amsterdam, NH, Netherlands | 2 days ago', '6,4\xa0χιλ. | N/A | N/A']
# ['Funda', 'Senior', '5-10  yrs', 'Amsterdam, NH, Netherlands | 2 days ago', '6,9\xa0χιλ. | N/A | 416,7']
# ['Booking.com', 'E', '1  yr', 'Amsterdam, NH, Netherlands | 2 days ago', '5\xa0χιλ. | N/A | N/A']
# ['ABN AMRO', '10', '10  yrs', 'Amsterdam, NH, Netherlands | 2 days ago', '7,9\xa0χιλ. | N/A | N/A']
# ['ServiceNow', 'IC4', '0  yrs', 'Amsterdam, NH, Netherlands | 2 days ago', '8,2\xa0χιλ. | 6,7\xa0χιλ. | 1,2\xa0χιλ.']
# ['TomTom', 'Software Engineer IV', '15  yrs', 'Amsterdam, NH, Netherlands | 2 days ago', '8,7\xa0χιλ. | N/A | 416,7']
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[4], line 13
#       8 time.sleep(2)
#      11 # the is at second page value should be set to False, apart for when scraping data from
#      12 # Germany, or the Netherlands
# ---> 13 data = scrape_pages_for_lyi(driver, is_at_second_page= True)
#      14 df = parse_list_to_df(data)
#
# File c:\Users\steve\web-scraping\salaries\salaries_functions.py:174, in scrape_pages_for_lyi(driver, is_at_second_page)
#     171 elements = list()
#     173 while True:
# --> 174     html = driver.page_source
#     175     soup = BeautifulSoup(html, 'html.parser')
#     176     try:
#
# File c:\Users\steve\web-scraping\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:570, in WebDriver.page_source(self)
#     562 @property
#     563 def page_source(self) -> str:
#     564     """Gets the source of the current page.
#     565
#     566     Example:
#     567     --------
#     568     >>> print(driver.page_source)
#     569     """
# --> 570     return self.execute(Command.GET_PAGE_SOURCE)["value"]
#
# File c:\Users\steve\web-scraping\.venv\Lib\site-packages\selenium\webdriver\remote\webdriver.py:429, in WebDriver.execute(self, driver_command, params)
#     427 response = self.command_executor.execute(driver_command, params)
#     428 if response:
# --> 429     self.error_handler.check_response(response)
#     430     response["value"] = self._unwrap_value(response.get("value", None))
#     431     return response
#
# File c:\Users\steve\web-scraping\.venv\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=139.0.7258.157)
# Stacktrace:
# 	GetHandleVerifier [0x0x7ff79acd3d85+79397]
# 	GetHandleVerifier [0x0x7ff79acd3de0+79488]
# 	(No symbol) [0x0x7ff79aa7c0fa]
# 	(No symbol) [0x0x7ff79aa54601]
# 	(No symbol) [0x0x7ff79ab0257e]
# 	(No symbol) [0x0x7ff79ab22c72]
# 	(No symbol) [0x0x7ff79aafaf73]
# 	(No symbol) [0x0x7ff79aac41b1]
# 	(No symbol) [0x0x7ff79aac4f43]
# 	GetHandleVerifier [0x0x7ff79af9e1ed+3005069]
# 	GetHandleVerifier [0x0x7ff79af9831d+2980797]
# 	GetHandleVerifier [0x0x7ff79afb7e0d+3110573]
# 	GetHandleVerifier [0x0x7ff79aced6de+184190]
# 	GetHandleVerifier [0x0x7ff79acf516f+215567]
# 	GetHandleVerifier [0x0x7ff79acdc974+115220]
# 	GetHandleVerifier [0x0x7ff79acdcb29+115657]
# 	GetHandleVerifier [0x0x7ff79acc3268+11016]
# 	BaseThreadInitThunk [0x0x7ffb2aa6e8d7+23]
# 	RtlUserThreadStart [0x0x7ffb2ac1c34c+44]

# %% [markdown]
# 5455

# %%
len(data)

# %% [markdown]
# 643

# %%
df.head(10)

# %%
edit_compensation_column(df)
edit_city(df)
add_country(df, f'{location}')
os.chdir('C:/Users/steve/web-scraping/misc')
df.to_csv(f'{location}.csv')

# %%
os.chdir('C:/Users/steve/web-scraping/database')




df = pd.read_csv(f'C:/Users/steve/web-scraping/misc/{location}.csv')
df = df.drop(columns='Unnamed: 0', axis=0)

df = df.rename(columns={
    "Company": "company_name",
    "Level": "title",
    "Years of Experience": "years_of_experience",
    "Total Compensation": "total_compensation",
    "Salary" : "salary"
})

df['country'] = f'{location}'
#df = df.drop(columns=f'{location}')

# %%
df.head(10)

# %%
df_to_sql(df, 'software_engineer_salaries')

# %%
driver.close()
