# %%
#paremeters
salaries_url = '1'
location = '2'

# %%
# Parameters
salaries_url = "https://levels.fyi/t/software-engineer/locations/london-metro-area"
location = "London Area"

# %%
from salaries_functions import *
import requests
import pprint
import selenium
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import os

from dotenv import load_dotenv


os.chdir('C:/Users/steve/web-scraping/database')

from crud_functions import write_dataframes_to_db, df_to_sql
from models import Software_Engineer_Levels_Fyi
from sqlalchemy import Engine

# %%
#salaries_url = 'https://www.levels.fyi/t/software-engineer/locations/netherlands'
driver = webdriver.Chrome()
sign_in_levels_fyi(driver)
driver.get(salaries_url)


driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)

data = scrape_pages_for_lyi(driver)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="45476c2eb1920a6c3ed9ae24e6f365c6", element="f.045BD43C156C9AC4999F44EA6B742CAB.d.2F0267D126F8632712A8A9A580475844.e.8")>
# Cookies accepted.
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ...
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page
# ['Samsung', 'L3', '3  yrs', 'London, EN, United Kingdom | 2 hours ago', '14,9\xa0χιλ. | N/A | 672,2']
# ['CrowdStrike', 'Senior Engineer I', '15  yrs', 'London, EN, United Kingdom | 3 hours ago', '11,5\xa0χιλ. | 8,9\xa0χιλ. | 1,6\xa0χιλ.']
# ['Morgan Stanley', 'L3', '1  yr', 'London, EN, United Kingdom | 8 hours ago', '6,7\xa0χιλ. | N/A | 667,9']
# ['Runway', 'L4', '10  yrs', 'London, EN, United Kingdom | 20 hours ago', '24,2\xa0χιλ. | N/A | N/A']
# ['ClearBank', 'L3', '3  yrs', 'London, EN, United Kingdom | 21 hours ago', '5,3\xa0χιλ. | N/A | 531,1']
# ['PlayStation', 'Senior Software Engineer', '12  yrs', 'London, EN, United Kingdom | 21 hours ago', '10,1\xa0χιλ. | N/A | N/A']
# ['Cognizant', 'hidden', '2-4  yrs', 'London, EN, United Kingdom | a day ago', '4,6\xa0χιλ. | N/A | N/A']
# ['Checkout.com', 'Software Engineer I', '4  yrs', 'London, EN, United Kingdom | a day ago', '5,9\xa0χιλ. | N/A | N/A']
# ['Teya', 'L3', '9  yrs', 'London, EN, United Kingdom | a day ago', '13,5\xa0χιλ. | 4,3\xa0χιλ. | 1,2\xa0χιλ.']
# skipped 1 page

# %% [markdown]
# 5455

# %%
len(data)
# Out:
# 900

# %% [markdown]
# 643

# %%
df = parse_list_to_df(data)

# %%
df.head(10)
# Out:
#           Company                     Level Years of Experience  \
# 0         Samsung                        L3              3  yrs
# 1     CrowdStrike         Senior Engineer I             15  yrs
# 2  Morgan Stanley                        L3               1  yr
# 3          Runway                        L4             10  yrs
# 4       ClearBank                        L3              3  yrs
# 5     PlayStation  Senior Software Engineer             12  yrs
# 6       Cognizant                    hidden            2-4  yrs
# 7    Checkout.com       Software Engineer I              4  yrs
# 8            Teya                        L3              9  yrs
# 9         Samsung                        L3              3  yrs
#
#                                         City               Total Compensation
# 0   London, EN, United Kingdom | 2 hours ago          14,9 χιλ. | N/A | 672,2
# 1   London, EN, United Kingdom | 3 hours ago  11,5 χιλ. | 8,9 χιλ. | 1,6 χιλ.
# 2   London, EN, United Kingdom | 8 hours ago           6,7 χιλ. | N/A | 667,9
# 3  London, EN, United Kingdom | 20 hours ago            24,2 χιλ. | N/A | N/A
# 4  London, EN, United Kingdom | 21 hours ago           5,3 χιλ. | N/A | 531,1
# 5  London, EN, United Kingdom | 21 hours ago            10,1 χιλ. | N/A | N/A
# 6     London, EN, United Kingdom | a day ago             4,6 χιλ. | N/A | N/A
# 7     London, EN, United Kingdom | a day ago             5,9 χιλ. | N/A | N/A
# 8     London, EN, United Kingdom | a day ago  13,5 χιλ. | 4,3 χιλ. | 1,2 χιλ.
# 9   London, EN, United Kingdom | 2 hours ago          14,9 χιλ. | N/A | 672,2

# %%
edit_compensation_column(df)
edit_city(df)
add_country(df, f'{location}')
os.chdir('C:/Users/steve/web-scraping/misc')
df.to_csv(f'{location}.csv')

# %%
os.chdir('C:/Users/steve/web-scraping/database')




df = pd.read_csv(f'C:/Users/steve/web-scraping/misc/{location}.csv')
df = df.drop(columns='Unnamed: 0', axis=0)

df = df.rename(columns={
    "Company": "company_name",
    "Level": "title",
    "Years of Experience": "years_of_experience",
    "Total Compensation": "total_compensation",
    "Salary" : "salary"
})

df['country'] = f'{location}'
#df = df.drop(columns=f'{location}')

# %%
df.head(10)
# Out:
#      company_name                     title years_of_experience  \
# 0         Samsung                        L3              3  yrs
# 1     CrowdStrike         Senior Engineer I             15  yrs
# 2  Morgan Stanley                        L3               1  yr
# 3          Runway                        L4             10  yrs
# 4       ClearBank                        L3              3  yrs
# 5     PlayStation  Senior Software Engineer             12  yrs
# 6       Cognizant                    hidden            2-4  yrs
# 7    Checkout.com       Software Engineer I              4  yrs
# 8            Teya                        L3              9  yrs
# 9         Samsung                        L3              3  yrs
#
#                           City               total_compensation  salary  \
# 0  London, EN, United Kingdom           14,9 χιλ. | N/A | 672,2    14.9
# 1  London, EN, United Kingdom   11,5 χιλ. | 8,9 χιλ. | 1,6 χιλ.    11.5
# 2  London, EN, United Kingdom            6,7 χιλ. | N/A | 667,9     6.7
# 3  London, EN, United Kingdom             24,2 χιλ. | N/A | N/A    24.2
# 4  London, EN, United Kingdom            5,3 χιλ. | N/A | 531,1     5.3
# 5  London, EN, United Kingdom             10,1 χιλ. | N/A | N/A    10.1
# 6  London, EN, United Kingdom              4,6 χιλ. | N/A | N/A     4.6
# 7  London, EN, United Kingdom              5,9 χιλ. | N/A | N/A     5.9
# 8  London, EN, United Kingdom   13,5 χιλ. | 4,3 χιλ. | 1,2 χιλ.    13.5
# 9  London, EN, United Kingdom           14,9 χιλ. | N/A | 672,2    14.9
#
#        country
# 0  London Area
# 1  London Area
# 2  London Area
# 3  London Area
# 4  London Area
# 5  London Area
# 6  London Area
# 7  London Area
# 8  London Area
# 9  London Area

# %%
df_to_sql(df, 'software_engineer_levels_fyi')

# %%
driver.close()
