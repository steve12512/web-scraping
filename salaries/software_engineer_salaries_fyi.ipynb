# %%
from salaries_functions import *
import requests
import pprint
import selenium
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import os

from dotenv import load_dotenv

# %%
salaries_url = 'https://www.levels.fyi/t/software-engineer/locations/germany'
driver = webdriver.Chrome()
sign_in_levels_fyi(driver)
driver.get(salaries_url)
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="50c298d086e90732a2759ba2ba0c57ed", element="f.A3399D0838BF1605132645AC4B26C73A.d.842E7D91ACD1E6D8B29D3B0A9C914E89.e.8")>
# Cookies accepted.

# %%
driver.close()
