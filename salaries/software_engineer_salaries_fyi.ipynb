# %%
from salaries_functions import *
import requests
import pprint
import selenium
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import os

from dotenv import load_dotenv

# %%
salaries_url = 'https://www.levels.fyi/t/software-engineer/locations/germany'
driver = webdriver.Chrome()
sign_in_levels_fyi(driver)
driver.get(salaries_url)


driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)  # Wait for JavaScript to load new data
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="eea24f479e9020e24a2dfc8bfbde2866", element="f.828E6A30BCBF1F2783C4E422E58D25EA.d.DC1A9BC9F3746454540C830D7AB17712.e.8")>
# Cookies accepted.

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')



rows = soup.find_all('tr', class_='salary-row_collapsedSalaryRow__o3k4j')

for row in rows:
    company_tag = row.find(class_='salary-row_companyName__8K8vS')  # Finds both <a> and <p>
    company = company_tag.get_text(strip=True) if company_tag else 'N/A'

    levels_tag = row.find(class_='salary-row_levelName__VZtUC')
    
    levels = levels_tag.get_text(strip=True) if levels_tag else 'N/A'
    
    yoe_tag = row.find('p', class_='css-4g68tt')
    yoe = yoe_tag.get_text(strip=True) if yoe_tag else 'N/A'
    
    total_compensation_tags = row.find_all('span', class_='css-b4wlzm')
    total_compensation = total_compensation_tags[2].get_text(strip=True) if total_compensation_tag else 'N/A'
    
    
    
    print(
        'Company name:', company,
        'Level :',
        levels,
        'Years of Experience :',yoe,
        'Total Compensation:' ,
        total_compensation)
# Out:
# Company name: Zalando Level : C7 Years of Experience : 10  yrs Total Compensation: 8,3 χιλ. | N/A | N/A
# Company name: 1&1 Mail & Media Level : Medior Years of Experience : 8  yrs Total Compensation: 6,1 χιλ. | N/A | N/A
# Company name: Align Technology Level : L7 Years of Experience : 10  yrs Total Compensation: 6,7 χιλ. | 833,3 | N/A
# Company name: Bosch Global Level : EG15 Years of Experience : 8  yrs Total Compensation: 8,5 χιλ. | N/A | N/A
# Company name: eBay Level : SE 3 Years of Experience : 10  yrs Total Compensation: 6,7 χιλ. | 916,7 | 250
# Company name: SAP SE Level : T4 Years of Experience : 8  yrs Total Compensation: 8,6 χιλ. | 1,1 χιλ. | 858,3
# Company name: GetYourGuide Level : L6 Years of Experience : 9  yrs Total Compensation: 9,2 χιλ. | 1,2 χιλ. | N/A
# Company name: SAP Level : T3 Years of Experience : 11  yrs Total Compensation: 7,4 χιλ. | 500 | N/A
# Company name: Leya Level : L5 Years of Experience : 15  yrs Total Compensation: 6,7 χιλ. | N/A | N/A

# %%
driver.close()

# %%
button = driver.find_element(By.CSS_SELECTOR, 'button.MuiButtonBase-root.MuiButton-sizeSmall')
button.click()

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())

# %%
driver.close()
