# %%
from salaries_functions import *
import requests
import pprint
import selenium
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException, ElementClickInterceptedException
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait
import os

from dotenv import load_dotenv

# %%
salaries_url = 'https://www.levels.fyi/t/software-engineer/locations/germany'
driver = webdriver.Chrome()
sign_in_levels_fyi(driver)
driver.get(salaries_url)


driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
time.sleep(2)  # Wait for JavaScript to load new data
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4740c01dacd0c49d03375cd50628c676", element="f.F0FD01A2B7DB148131207F32B9762CED.d.621AE623FB71D35CC58C29DDA22B24E1.e.9")>
# Cookies accepted.

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')



rows = soup.find_all('tr', class_='salary-row_collapsedSalaryRow__o3k4j')
print(len(rows))

for row in rows:
    company_tag = row.find('a', class_='salary-row_linkedCompany__c4yab')
    company = company_tag.get_text(strip=True) if company_tag else 'N/A'

    print(company)
# Out:
# 8
# N/A
# Align Technology
# Bosch Global
# eBay
# N/A
# GetYourGuide
# SAP
# N/A

# %%
driver.close()

# %%
button = driver.find_element(By.CSS_SELECTOR, 'button.MuiButtonBase-root.MuiButton-sizeSmall')
button.click()

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
print(soup.prettify())

# %%
driver.close()
